# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
import os
import pandas as pd
# Print current working directory and files to verify location
print('CWD:', os.getcwd())
print('Files in CWD:')
for f in os.listdir():
    print('-', f)
# Resolve the relative path and try to read the CSV without leading slash
csv_name = 'gdp-vs-happiness.csv'
print('Resolved path:', os.path.abspath(csv_name))
try:
    df = pd.read_csv(csv_name)
    print('\nLoaded DataFrame (first 5 rows):')
    print(df.head())
except FileNotFoundError as e:
    print('\nFileNotFoundError:', e)
    print('If this file is not in the notebook folder, try this full path:')
    print(r"C:\Users\Nehal\Desktop\ResumeProjects\Money can buy happiness\gdp-vs-happiness.csv")
except Exception as e:
    print('\nError reading CSV:', type(e).__name__, e)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1276393886.py in <cell line: 0>()
# ----> 1 df = pd.read_csv(gdp-vs-happiness.csv)
#
# NameError: name 'gdp' is not defined
